# %%
import pandas as pd

# %%
data = pd.read_csv('./wfp_food_prices_col.csv')
dataLimpia = pd.read_csv('./wfp_food_prices_col_limpio.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39771 entries, 0 to 39770
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       39771 non-null  object
#  1   admin1     39771 non-null  object
#  2   admin2     39771 non-null  object
#  3   market     39771 non-null  object
#  4   latitude   39771 non-null  object
#  5   longitude  39771 non-null  object
#  6   category   39771 non-null  object
#  7   commodity  39771 non-null  object
#  8   unit       39771 non-null  object
#  9   priceflag  39771 non-null  object
#  10  pricetype  39771 non-null  object
#  11  currency   39771 non-null  object
#  12  price      39771 non-null  object
#  13  usdprice   39771 non-null  object
# dtypes: object(14)
# memory usage: 4.2+ MB

# %%
dataLimpia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39206 entries, 0 to 39205
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       39206 non-null  object
#  1   admin1     39206 non-null  object
#  2   admin2     39206 non-null  object
#  3   market     39206 non-null  object
#  4   latitude   39206 non-null  float64
#  5   longitude  39206 non-null  float64
#  6   category   39206 non-null  object
#  7   commodity  39206 non-null  object
#  8   unit       39206 non-null  object
#  9   priceflag  39206 non-null  object
#  10  pricetype  39206 non-null  object
#  11  currency   39206 non-null  object
#  12  price      39206 non-null  float64
#  13  usdprice   39206 non-null  float64
# dtypes: float64(4), object(10)
# memory usage: 4.2+ MB

# %%
data.describe()
# Out:
#               date        admin1        admin2  market latitude   longitude
# count        39771         39771         39771   39771    39771       39771  \
# unique         300            23            28      28       28          28
# top     2020-04-15  Bogotá, D.c.  Bogotá, D.c.  Bogota      4.6  -74.083333
# freq           601          5231          5231    5231     5231        5231
#
#                      category    commodity   unit  priceflag  pricetype
# count                   39771        39771  39771      39771      39771  \
# unique                      9           87     11          4          3
# top     vegetables and fruits  Wheat flour     KG  aggregate  Wholesale
# freq                    14058         1461  36328      29722      39708
#
#        currency   price usdprice
# count     39771   39771    39771
# unique        2   29889    22040
# top         COP  2000.0   0.3764
# freq      39770     258       14

# %%
data
# Out:
#              date           admin1
# 0           #date       #adm1+name  \
# 1      2000-01-15        Antioquia
# 2      2000-01-15        Atlántico
# 3      2000-01-15        Atlántico
# 4      2000-01-15     Bogotá, D.c.
# ...           ...              ...
# 39766  2024-11-15  Valle Del Cauca
# 39767  2024-11-15  Valle Del Cauca
# 39768  2024-11-15  Valle Del Cauca
# 39769  2024-11-15  Valle Del Cauca
# 39770  2024-11-15  Valle Del Cauca
#
#                                                   admin2            market
# 0                                             #adm2+name  #loc+market+name  \
# 1                                               Medellín          Medellin
# 2      Distrito Especial, Industrial Y Portuario De B...      Barranquilla
# 3      Distrito Especial, Industrial Y Portuario De B...      Barranquilla
# 4                                           Bogotá, D.c.            Bogota
# ...                                                  ...               ...
# ...

# %%
data_util = data[["usdprice", "commodity", "date", "unit"]]
data_util.to_csv('./wfp_food_prices_col_.csv', index=False)
# Out:
# '999.3296'
